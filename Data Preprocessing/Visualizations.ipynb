# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv(r"C:\Users\Thangsnivi\3D Objects\Admission_Predict.csv")

# %%
plt.scatter(data['GRE Score'],data['CGPA'],color = "pink")
plt.title('CGPA vs GRE Score')
plt.xlabel('GRE Score')
plt.ylabel('CGPA')
plt.show()

# %%
data["GRE Score"].plot(kind = 'hist',bins = 200,figsize = (6,6),color="blue")

plt.title("GRE Scores")
plt.xlabel("GRE Score")
plt.ylabel("Frequency")

plt.show()

# %%
data.Research.value_counts()

sns.countplot(x="University Rating",data=data)
# Out:
# <AxesSubplot:xlabel='University Rating', ylabel='count'>
